# %% [markdown]
# Nizam shaikh - 24198170

# %% [markdown]
# Write a Python program that prints "Hello, World!" to the console.

# %%
"Hello, World!"
# Out:
# 'Hello, World!'

# %% [markdown]
# Develop a function that determines whether a given integer is even or odd.

# %%
even = [2, 4, 6, 8]
odd = [1, 3, 5, 7, 9]
a = 4
if a in even:
    print("a is even"),
else:
    print("a is odd")
# Out:
# a is even

# %% [markdown]
# Create a program that takes two numbers as input and displays their sum, difference, product, and quotient.

# %%
n1 = 7
n2 = 8
print([n1+n2,
       n1-n2,
      n1*n2,
       n1/n2])
# Out:
# [15, -1, 56, 0.875]

# %% [markdown]
# Initialize a list with five integers.
# Append a new integer to the list.
# Remove the second item from the list.
# Sort the list in ascending order.
# Print the final list.

# %%
n_list = [1, 2, 3, 4,5]
n_list.append(6)
n_list.pop(1)
n_list.sort()
print(n_list)
# Out:
# [1, 3, 4, 5, 6]

# %% [markdown]
# Write a function that takes a string as input and returns the string reversed.

# %%
a = "nizam"
def reverse_string(text):
    return text[::-1]
print(reverse_string(a))
# Out:
# mazin

# %% [markdown]
# Load a CSV File

# %%
import pandas as pd
df = pd.read_csv("Crime offense.csv")
df.head()
# Out:
#   STATISTIC           Statistic Label  TLIST(Q1) Quarter  C02479V04377  \
# 0     CJQ05  Recorded crime incidents      20031  2003Q1            10
# 1     CJQ05  Recorded crime incidents      20031  2003Q1            10
# 2     CJQ05  Recorded crime incidents      20031  2003Q1            10
# 3     CJQ05  Recorded crime incidents      20031  2003Q1            10
# 4     CJQ05  Recorded crime incidents      20031  2003Q1            10
#
#                     Garda Region C02480V03003  \
# 0  10 Dublin Metropolitan Region            1
# 1  10 Dublin Metropolitan Region          111
# 2  10 Dublin Metropolitan Region          112
# 3  10 Dublin Metropolitan Region          113
# 4  10 Dublin Metropolitan Region           12
#
#                             Type of Offence    UNIT  VALUE
# 0          Homicide & related offences (01)  Number    7.0
# 1                             Murder (0111)  Number    4.0
# 2                       Manslaughter (0112)  Number    2.0
# ...

# %% [markdown]
# Check the number of rows and columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25920 entries, 0 to 25919
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   STATISTIC        25920 non-null  object
#  1   Statistic Label  25920 non-null  object
#  2   TLIST(Q1)        25920 non-null  int64
#  3   Quarter          25920 non-null  object
#  4   C02479V04377     25920 non-null  int64
#  5   Garda Region     25920 non-null  object
#  6   C02480V03003     25920 non-null  object
#  7   Type of Offence  25920 non-null  object
#  8   UNIT             25920 non-null  object
#  9   VALUE            25872 non-null  float64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 2.0+ MB
